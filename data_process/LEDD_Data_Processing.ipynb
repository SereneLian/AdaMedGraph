# %% [markdown]
# Notebook to process the levodopa equivalent dose information from PPMI.

# %%
import numpy as np
import pandas as pd
from calc_ledd import calc_ledd

# %% [markdown]
# ### Demographics
# Use preprocessed demographics. Enrolled patients have an enroll date that is not null.

# %%
path = ''
demo = pd.read_csv(path+'processed/demographics.csv') #note that this is the processed data created by 'Demographics_Data_Processing.ipynb
demo
# Out:
#        PATNO ENROLL_DATE  ENROLL_AGE ENROLL_STATUS STATUS_DATE  COHORT  \
# 0       3000     02/2011        69.1      enrolled     05/2021     2.0
# 1       3001     03/2011        65.1      enrolled     09/2021     1.0
# 2       3002     03/2011        67.6      enrolled     09/2021     1.0
# 3       3003     04/2011        56.7      enrolled     01/2022     1.0
# 4       3004     04/2011        59.4      enrolled     01/2022     2.0
# ...      ...         ...         ...           ...         ...     ...
# 2018  173487     10/2022        70.9      enrolled     10/2022     1.0
# 2019  174364     10/2022        70.1      enrolled     10/2022     1.0
# 2020  174811     10/2022        76.0      enrolled     10/2022     4.0
# 2021  174855     10/2022        64.2      enrolled     10/2022     1.0
# 2022  174871     10/2022        76.1      enrolled     10/2022     1.0
#
#       APPRDX  BIRTHDT  SEX  DOMSIDE
# 0        2.0  12/1941  0.0      NaN
# 1        1.0  01/1946  1.0      2.0
# 2        1.0  08/1943  0.0      1.0
# 3        1.0  07/1954  0.0      2.0
# 4        2.0  11/1951  1.0      NaN
# ...      ...      ...  ...      ...
# 2018     NaN  12/1951  0.0      NaN
# 2019     NaN  09/1952  1.0      NaN
# 2020     NaN  10/1946  0.0      NaN
# 2021     NaN  08/1958  1.0      NaN
# 2022     NaN  09/1946  1.0      NaN
#
# [2023 rows x 10 columns]

# %% [markdown]
# ### Concomitant Medications

# %%
con_med = pd.read_csv(path + 'LEDD_Concomitant_Medication_Log.csv')
con_med.head(4)
# Out:
#       REC_ID  PATNO EVENT_ID PAG_NAME INFODT  SEQNO  \
# 0  501974201   3001      LOG     CMED    NaN     18
# 1  413441801   3001      LOG     CMED    NaN     14
# 2  370113101   3001      LOG     CMED    NaN     11
# 3  516506501   3001      LOG     CMED    NaN     19
#
#                           LEDTRT  LEDDSTRMG LEDDOSSTR  LEDDOSE  LEDDOSFRQ  \
# 0                 SINEMET 25/100        NaN       NaN      NaN        NaN
# 1  ROTIGOTINE TRANSDERMAL SYSTEM        NaN       NaN      NaN        NaN
# 2                     SELEGILINE        NaN       NaN      NaN        NaN
# 3                 SINEMET 25/100        NaN       NaN      NaN        NaN
#
#    STARTDT   STOPDT    LEDD ORIG_ENTRY            LAST_UPDATE
# 0  12/2014  03/2015  300.00    02/2015  2020-06-25 16:04:31.0
# 1  09/2013  10/2013  121.20    10/2013  2020-06-25 16:04:31.0
# 2  08/2012  06/2020  100.00    11/2012  2022-09-13 07:29:02.0
# 3  03/2015  03/2016  400.00    04/2015  2020-06-25 16:04:31.0

# %% [markdown]
# DISMED is a flag as to whether or not the medication is for PD. LEDD contains the levodopa equivalent daily dose (LEDD).

# %% [markdown]
# Data we're intested in PATNO, EVENT_ID, LEDD, STARTDT, STARTEST, STOPDT, STOPEST, CMTRT, CMDOSE, CMDOSU, ONGOING for only PD medications and patients who are enrolled.

# %%
# cm = con_med[(con_med.DISMED==1) | ((con_med.DISMED.isnull()) & (~con_med.LEDD.isnull()))].merge(enrol_pat[['APPRDX','PATNO']], on=["PATNO"])
con_med = con_med[(~con_med.LEDD.isnull())]
con_med
# Out:
#                                     REC_ID   PATNO EVENT_ID PAG_NAME   INFODT  \
# 0                                501974201    3001      LOG     CMED      NaN
# 1                                413441801    3001      LOG     CMED      NaN
# 2                                370113101    3001      LOG     CMED      NaN
# 3                                516506501    3001      LOG     CMED      NaN
# 4                                733300401    3001      LOG     CMED      NaN
# ...                                    ...     ...      ...      ...      ...
# 6654  dd2eb794-3024-4c68-9c05-aebe909ddcde  150110       SC  LEDDLOG  08/2022
# 6655  e3c72762-90ec-48c4-9279-9f0787c9b621  158434       SC  LEDDLOG  06/2022
# 6656  25745afa-1ee4-4c8a-91dd-794802b03eb4  158434       SC  LEDDLOG  06/2022
# 6657  d01cd45e-6dd8-4fcc-9da9-a395ba56cb28  158449       SC  LEDDLOG  06/2022
# 6658  7d13e530-796d-46ba-adbe-45192499112f  158449       SC  LEDDLOG  06/2022
#
#       SEQNO                          LEDTRT  LEDDSTRMG       LEDDOSSTR  \
# 0        18                  SINEMET 25/100        NaN             NaN
# 1        14   ROTIGOTINE TRANSDERMAL SYSTEM        NaN             NaN
# 2        11                      SELEGILINE        NaN             NaN
# 3        19                  SINEMET 25/100        NaN             NaN
# 4        31                      AMANTADINE        NaN             NaN
# ...     ...                             ...        ...             ...
# 6654      1     Rytary (Carbidopa/Levodopa)     95.000  23.75/95 mg PO
# 6655      1            Azilect (Rasagiline)      1.000         1 mg PO
# 6656      0                  Pramipexole ER      0.750      0.75 mg PO
# 6657      0            Sifrol (Pramipexole)      0.125     0.125 mg PO
# 6658      1  Prolopa (Levodopa/Benserazide)    200.000    200/50 mg PO
#
#       LEDDOSE  LEDDOSFRQ  STARTDT   STOPDT    LEDD ORIG_ENTRY  \
# 0         NaN        NaN  12/2014  03/2015  300.00    02/2015
# 1         NaN        NaN  09/2013  10/2013  121.20    10/2013
# 2         NaN        NaN  08/2012  06/2020  100.00    11/2012
# 3         NaN        NaN  03/2015  03/2016  400.00    04/2015
# 4         NaN        NaN  07/2018  06/2020  200.00    03/2019
# ...       ...        ...      ...      ...     ...        ...
# 6654      2.0        2.0  07/2022      NaN   266.0    08/2022
# 6655      1.0        1.0  03/2022  06/2022   100.0    07/2022
# 6656      1.0        1.0  03/2022  06/2022    75.0    07/2022
# 6657      1.0        1.0  12/2021  01/2022    12.5    06/2022
# 6658      1.0        3.0  11/2021  01/2022   600.0    06/2022
#
#                 LAST_UPDATE
# 0     2020-06-25 16:04:31.0
# 1     2020-06-25 16:04:31.0
# 2     2022-09-13 07:29:02.0
# 3     2020-06-25 16:04:31.0
# 4     2022-09-13 07:29:02.0
# ...                     ...
# 6654  2022-08-09 00:00:00.0
# 6655  2022-07-14 00:00:00.0
# 6656  2022-07-14 00:00:00.0
# 6657  2022-06-28 00:00:00.0
# 6658  2022-06-28 00:00:00.0
#
# [6560 rows x 16 columns]

# %%
cm=con_med.merge(demo[['COHORT','PATNO']], on=["PATNO"]) 
len(cm)
# Out:
# 6542

# %%
PD_records = cm[cm.COHORT==1].groupby('PATNO')

# %%
counts_per_patient = PD_records.STARTDT.count().value_counts(sort=False)
PD_pat = demo[demo.COHORT==1.0]

# %% [markdown]
# Calculate LEDD for each patno date combination in the signature form

# %%
signature = pd.read_csv(path + 'processed/pd_on.csv')
signature.head()
# Out:
# /Users/serenelian/Downloads/ENTER/envs/lunggraph/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (3,4,5,6,7,38,39,77,120) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    PATNO EVENT_ID   INFODT NP1COG NP1HALL NP1DPRS NP1ANXS NP1APAT NP1DDS  \
# 0   3001       BL  03/2011      0       0       0       0       0      0
# 1   3001      R17  11/2021      2       1       2       2       2      0
# 2   3001      R18  09/2022      2       1       1       2       3      1
# 3   3001       SC  02/2011      0       0       0       1       0      0
# 4   3001      V01  05/2011      0       0       0       0       0      0
#
#    NP1RTOT  ...  DATSCAN_DATE  DATSCAN_CAUDATE_R  DATSCAN_CAUDATE_L  \
# 0      0.0  ...           NaN                NaN                NaN
# 1      9.0  ...           NaN                NaN                NaN
# 2     10.0  ...           NaN                NaN                NaN
# 3      1.0  ...           NaN                NaN                NaN
# 4      0.0  ...           NaN                NaN                NaN
#
#    DATSCAN_PUTAMEN_R  DATSCAN_PUTAMEN_L  DATSCAN_PUTAMEN_R_ANT  \
# 0                NaN                NaN                    NaN
# 1                NaN                NaN                    NaN
# 2                NaN                NaN                    NaN
# 3                NaN                NaN                    NaN
# 4                NaN                NaN                    NaN
#
#    DATSCAN_PUTAMEN_L_ANT  DATSCAN_ANALYZED  DATSCAN_NOT_ANALYZED_REASON  \
# 0                    NaN               NaN                          NaN
# 1                    NaN               NaN                          NaN
# 2                    NaN               NaN                          NaN
# 3                    NaN               NaN                          NaN
# 4                    NaN               NaN                          NaN
#
#    DATSCAN_OTHER_SPECIFY
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 131 columns]

# %%
ledd_processed = pd.DataFrame(columns=['PATNO','EVENT_ID','INFODT','LEDD'])
cm.STARTDT = pd.to_datetime(cm.STARTDT)
cm.STOPDT = pd.to_datetime(cm.STOPDT)

# %%
cm[cm.PATNO==3001]
# Out:
#                                   REC_ID  PATNO EVENT_ID PAG_NAME   INFODT  \
# 0                              501974201   3001      LOG     CMED      NaN
# 1                              413441801   3001      LOG     CMED      NaN
# 2                              370113101   3001      LOG     CMED      NaN
# 3                              516506501   3001      LOG     CMED      NaN
# 4                              733300401   3001      LOG     CMED      NaN
# 5                              468228001   3001      LOG     CMED      NaN
# 6                              413441701   3001      LOG     CMED      NaN
# 7                              370113001   3001      LOG     CMED      NaN
# 8                              559553601   3001      LOG     CMED      NaN
# 9   6dda354e-db2b-4ecf-a057-a2044548395e   3001      V18  LEDDLOG  07/2022
# 10  cf3ee87c-5fcc-43a2-87c5-3100d9e2405f   3001      V18  LEDDLOG  07/2022
# 11  2c2cbae6-e268-4fd7-96d4-0bbe13fe22c9   3001      V18  LEDDLOG  07/2022
#
#     SEQNO                         LEDTRT  LEDDSTRMG     LEDDOSSTR  LEDDOSE  \
# 0      18                 SINEMET 25/100        NaN           NaN      NaN
# 1      14  ROTIGOTINE TRANSDERMAL SYSTEM        NaN           NaN      NaN
# 2      11                     SELEGILINE        NaN           NaN      NaN
# 3      19                 SINEMET 25/100        NaN           NaN      NaN
# 4      31                     AMANTADINE        NaN           NaN      NaN
# 5      15  ROTIGOTINE TRANSDERMAL SYSTEM        NaN           NaN      NaN
# 6      13  ROTIGOTINE TRANSDERMAL SYSTEM        NaN           NaN      NaN
# 7      10                     SELEGILINE        NaN           NaN      NaN
# 8      20                 SINEMET 25/100        NaN           NaN      NaN
# 9       1          Carbidopa/Levodopa CR      100.0  25/100 mg PO      1.0
# 10      2                     Amantadine      100.0     100 mg PO      1.0
# 11      0                     Amantadine      100.0     100 mg PO      1.0
#
#     LEDDOSFRQ    STARTDT     STOPDT                LEDD ORIG_ENTRY  \
# 0         NaN 2014-12-01 2015-03-01              300.00    02/2015
# 1         NaN 2013-09-01 2013-10-01              121.20    10/2013
# 2         NaN 2012-08-01 2020-06-01              100.00    11/2012
# 3         NaN 2015-03-01 2016-03-01              400.00    04/2015
# 4         NaN 2018-07-01 2020-06-01              200.00    03/2019
# 5         NaN 2013-10-01 2014-12-01              181.80    10/2014
# 6         NaN 2013-08-01 2013-09-01               60.60    10/2013
# 7         NaN 2012-07-01 2012-08-01               50.00    11/2012
# 8         NaN 2016-03-01 2020-06-01              600.00    03/2016
# 9         7.0 2017-01-01        NaT  489.99999999999994    12/2021
# 10        1.0 2022-03-01        NaT               100.0    07/2022
# 11        2.0 2018-01-01 2022-03-01               200.0    12/2021
#
#               LAST_UPDATE  COHORT
# 0   2020-06-25 16:04:31.0     1.0
# 1   2020-06-25 16:04:31.0     1.0
# 2   2022-09-13 07:29:02.0     1.0
# 3   2020-06-25 16:04:31.0     1.0
# 4   2022-09-13 07:29:02.0     1.0
# 5   2020-06-25 16:04:31.0     1.0
# 6   2020-06-25 16:04:31.0     1.0
# 7   2020-06-25 16:04:31.0     1.0
# 8   2022-09-13 07:29:02.0     1.0
# 9   2022-01-06 00:00:00.0     1.0
# 10  2022-07-08 00:00:00.0     1.0
# 11  2022-07-08 00:00:00.0     1.0

# %%
for idx in signature.index:
    pn = signature.loc[idx].PATNO
    ei = signature.loc[idx].EVENT_ID
    idt = signature.loc[idx].INFODT
    ledd = calc_ledd(cm, pn, pd.to_datetime(idt))
    ledd_processed = ledd_processed.append({'PATNO':pn, 'EVENT_ID':ei, 'INFODT': idt, 'LEDD':ledd},
                                   ignore_index=True)

# %%
ledd_processed.drop_duplicates(inplace=True)

# %%
ledd_processed.to_csv('ledd.csv')
